# %% [markdown]
# <a href="https://colab.research.google.com/github/gus-arellano/TALLER/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as xd
import matplotlib.pyplot as ltv

link="https://github.com/seismomat/HerramientasComputacionales/blob/main/Aplicaciones/ebola_outbreak_dataset-master/ebola_outbreak_dataset-master/ebola_2014_2016_clean.csv"
code="?raw=true"
url= link+code
df= xd.read_csv(url,sep=",",index_col=1)
df
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.tail()
# Out:
#                              Country  No. of confirmed cases  \
# Date
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2016-03-23                      NaN
# 2016-03-23                      NaN
# 2016-03-23                      1.0
# 2016-03-23                      7.0
# 2016-03-23                      1.0

# %%
df.info
# Out:
# <bound method DataFrame.info of                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                              Country  No. of confirmed cases  \
# Date
# 2014-08-29                    Guinea                   482.0
# 2014-08-29                   Nigeria                    15.0
# 2014-08-29              Sierra Leone                   935.0
# 2014-08-29                   Liberia                   322.0
# 2014-09-05                    Guinea                   604.0
# ...                              ...                     ...
# 2016-03-23                   Liberia                  3151.0
# 2016-03-23                     Italy                     1.0
# 2016-03-23                   Liberia                     2.0
# 2016-03-23                   Nigeria                    19.0
# 2016-03-23  United States of America                     4.0
#
#             No. of confirmed deaths
# Date
# 2014-08-29                    287.0
# 2014-08-29                      6.0
# 2014-08-29                    380.0
# 2014-08-29                    225.0
# ...

# %%
df.isnull().sum()
# Out:
# Country                      0
# No. of confirmed cases       0
# No. of confirmed deaths    836
# dtype: int64

# %%
df['Country']
# Out:
# Date
# 2014-08-29                      Guinea
# 2014-08-29                     Nigeria
# 2014-08-29                Sierra Leone
# 2014-08-29                     Liberia
# 2014-09-05                      Guinea
#                         ...
# 2016-03-23                     Liberia
# 2016-03-23                       Italy
# 2016-03-23                     Liberia
# 2016-03-23                     Nigeria
# 2016-03-23    United States of America
# Name: Country, Length: 2484, dtype: object

# %%
NIG=df[df["Country"]=="Nigeria"]
NIG.head()
# Out:
#             Country  No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29  Nigeria                    15.0                      6.0
# 2014-09-05  Nigeria                    18.0                      7.0
# 2014-09-08  Nigeria                    19.0                      7.0
# 2014-09-12  Nigeria                    19.0                      7.0
# 2014-09-16  Nigeria                    19.0                      7.0

# %%
"""Para borrar la columna del nombre Sierra Leone"""
NIG=NIG.drop("Country", axis=1)
NIG.head()
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-08-29                    15.0                      6.0
# 2014-09-05                    18.0                      7.0
# 2014-09-08                    19.0                      7.0
# 2014-09-12                    19.0                      7.0
# 2014-09-16                    19.0                      7.0

# %%
NIG[10:20]
# Out:
#             No. of confirmed cases  No. of confirmed deaths
# Date
# 2014-10-03                    19.0                      7.0
# 2014-10-08                    19.0                      7.0
# 2014-10-10                    19.0                      7.0
# 2014-10-15                    19.0                      7.0
# 2014-10-17                    19.0                      7.0
# 2014-10-22                    19.0                      7.0
# 2014-10-25                    19.0                      7.0
# 2014-10-29                    19.0                      7.0
# 2014-10-31                    19.0                      7.0
# 2014-11-05                    19.0                      7.0

# %%
NIG.isnull().sum()
# Out:
# No. of confirmed cases     0
# No. of confirmed deaths    0
# dtype: int64

# %%
Guin=df[df["Country"]=="Guinea"]
Guin.isnull().sum()
# Out:
# Country                    0
# No. of confirmed cases     0
# No. of confirmed deaths    2
# dtype: int64

# %%
NIG['No. of confirmed cases'].mean()
# Out:
# 18.980392156862745

# %%
NIG['No. of confirmed deaths'].mean()
# Out:
# 6.996078431372549

# %%
Dates=NIG.index[0:-1:10]
NCC=NIG['No. of confirmed cases'][0:-1:10]
NCD=NIG['No. of confirmed deaths'][0:-1:10]
ltv.plot(Dates,NCC,"o--r",ms=2,label="Infectados")
ltv.plot(Dates,NCD,"o-k",ms=4, label="Muertes")
ltv.grid()
ltv.title("Avance del ebola en Nigeria")
ltv.ylabel("Casos confirmados")
ltv.xlabel("Periodo de tiempo")
ltv.xticks(rotation=90, fontsize=7)
ltv.legend()
ltv.show()
